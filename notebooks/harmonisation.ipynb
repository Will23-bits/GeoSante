# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Notebook — Harmonisation des données (squelette)\n",
#     "\n",
#     "Ce notebook décrit la méthodologie d'harmonisation des jeux de données grippe et vaccination et donne un exemple d'utilisation du module `src/data/harmonize.ts`. Il est livré comme squelette documentaire pour la démonstration au jury.\n"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## Objectifs\n",
#     "- Documenter les étapes ETL nécessaires (normalisation dates → semaine ISO, standardisation des régions, mapping des tranches d'âge, calculs dérivés).\n",
#     "- Fournir un exemple minimal de code pour harmoniser des jeux bruts et générer `data/processed/`.\n",
#     "- Indiquer les contrôles qualité et les seuils d'alerte recommandés.\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "// Exemple d'utilisation (TypeScript) — documentatif\n",
#     "// copier ce snippet dans un script TypeScript ou un notebook avec kernel TypeScript\n",
#     "import { harmonizeFlu, harmonizeVaccination, joinFluVaccination } from '../src/data/harmonize';\n",
#     "\n",
#     "// Exemple de données brutes (mini jeu)\n",
#     "const rawFlu = [\n",
#     "  { date: '2024-01-15', regionCode: 'FR-84', age: '65+', cases: 120, population: 50000 },\n",
#     "  { date: '2024-01-15', regionCode: 'FR-75', age: '18-49', cases: 300, population: 200000 }\n",
#     "];\n",
#     "\n",
#     "const rawVac = [\n",
#     "  { date: '2024-01-12', regionCode: 'FR-84', age: '65+', vaccine: 'Influenza', dosesAdmin: 15000, populationTarget: 50000 },\n",
#     "  { date: '2024-01-12', regionCode: 'FR-75', age: '18-49', vaccine: 'Influenza', dosesAdmin: 50000, populationTarget: 200000 }\n",
#     "];\n",
#     "\n",
#     "// Harmonisation\n",
#     "const flu = harmonizeFlu(rawFlu);\n",
#     "const vac = harmonizeVaccination(rawVac);\n",
#     "// Jointure (par défaut non par âge)\n",
#     "const combined = joinFluVaccination(flu, vac, true);\n",
#     "console.log('Combined sample:', combined);\n"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## Contrôles qualité recommandés\n",
#     "- Vérifier les semaines invalides (`week === 'INVALID'`).\n",
#     "- Contrôler la présence de `regionCode` non reconnus (`UNK`).\n",
#     "- Vérifier les bornes de `coveragePct` (0–100).\n",
#     "\n",
#     "## Export des données traitées\n",
#     "Après harmonisation, exporter `combined` en CSV/JSON dans `data/processed/` pour consommation par l'application React.\n"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.8"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
